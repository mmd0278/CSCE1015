# %% [markdown]
# <a href="https://colab.research.google.com/github/mmd0278/CSCE1015/blob/main/Copy_of_INFO4670_Week3_Assignment1_Template.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Assignment 1 — Making Sense of Northgate through Visualization
# **INFO 4670 · Data Analysis and Knowledge Discovery**  ·  **Due: Sunday, 11:59 PM**
#
# **Name:** Merveille Dedieu    **Date:** September 6, 2026
#
# **The situation.** The Provost's question stands: *which students are struggling, and can we see it earlier?* This week you answer it the way analysts do — not by reading rows, but by drawing the data. Every chart below is built by **adapting code from the Guided notebook**; the intellectual work is choosing the right chart and reading it honestly.
#
# **For every chart you make, you must:**
# 1. **Choose** the chart type that fits the variable(s) and the question.
# 2. **Build** it in Colab from the Northgate files.
# 3. **Label** it fully — title, axis labels, and units/legend. *An unlabeled chart is an unfinished chart.*
# 4. **Write a STAR story** underneath it — Scope · Track · Articulate · Respond (defined on the Concepts deck).
#
# **How to work:** run Setup and Load first. Then, for each question, copy the closest cell from the Guided notebook into the empty cell, adapt it, and fill in the STAR cell below it.
#
# **Submit:** push this notebook to GitHub and submit the **GitHub link** in Canvas. (See the setup doc: *Colab_GitHub_Setup_INFO4670_Fall2026*.)

# %% [markdown]
# ## Setup — run this first (you don't need to change it)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Northgate house style (optional, but keeps your charts consistent)
NAVY = "#22303A"
RUST = "#C0562F"
sns.set_theme(style="whitegrid")
plt.rcParams["figure.figsize"]   = (8, 5)
plt.rcParams["axes.titlesize"]   = 13
plt.rcParams["axes.titleweight"] = "bold"

# %% [markdown]
# ## Load the data — run this, then look before you plot

# %%
# STEP 1 — get the data into this notebook. Pick ONE option, then run.

DATA_DIR = "."   # OPTION 2 (default) · drag the 3 CSVs into the file panel on the left

# OPTION 1 · read from Google Drive — uncomment and edit the path:
# from google.colab import drive
# drive.mount("/content/drive")
# DATA_DIR = "/content/drive/MyDrive/.../Data"

import os
students = pd.read_csv(os.path.join(DATA_DIR, "student_records.csv"))
weekly   = pd.read_csv(os.path.join(DATA_DIR, "weekly_activity.csv"))
students.head()
# Out:
#   student_id                   major  age      housing  commute_miles  \
# 0  NU-101508            Data Science   27   Off-Campus            7.6
# 1  NU-102438   Learning Technologies   25  With Family           14.3
# 2  NU-102385   Learning Technologies   26  With Family            3.4
# 3  NU-100767          Cyber Security   22    On-Campus           23.7
# 4  NU-106054  Information Technology   21   Off-Campus            2.3
#
#    work_hours_per_week  advisor_meetings  credits_attempted  final_gpa  \
# 0                   15                 1                 81       1.86
# 1                   35                 1                100       2.06
# 2                   18                 9                 77       3.41
# 3                   40                 1                 65       1.73
# 4                   20                 4                 59       2.37
#
#    study_hours_reported enrollment_date  dropped_out
# 0                   NaN      2023-09-13            1
# 1                   9.5      2023-10-19            0
# 2                  19.1      11/16/2022            0
# 3                   8.1      2024-05-03            0
# 4                   6.6      10/24/2022            0

# %%
# how many rows, which columns, what types?
students.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2027 entries, 0 to 2026
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   student_id            2027 non-null   object
#  1   major                 2027 non-null   object
#  2   age                   2027 non-null   int64
#  3   housing               2027 non-null   object
#  4   commute_miles         2027 non-null   float64
#  5   work_hours_per_week   2027 non-null   int64
#  6   advisor_meetings      2027 non-null   int64
#  7   credits_attempted     2027 non-null   int64
#  8   final_gpa             2027 non-null   float64
#  9   study_hours_reported  1772 non-null   float64
#  10  enrollment_date       2027 non-null   object
#  11  dropped_out           2027 non-null   int64
# dtypes: float64(3), int64(5), object(4)
# memory usage: 190.2+ KB

# %% [markdown]
# # Part A — Guided questions
# Build **one chart per question**. Each maps to one chart family from this week. Copy the closest Guided-notebook cell, adapt it, label it, then write its STAR story.

# %% [markdown]
# ### Q1 · One quantitative variable
# **How many hours per week do Northgate students work?** Describe what's typical, how spread out it is, and whether anyone stands apart.
# → *histogram* (add a *box plot* if it helps). Column: `work_hours_per_week` (from `students`).

# %%
# Copy the closest cell from the Guided notebook, then fill in the blanks.
#
#   fig, ax = plt.subplots()
#   sns.__________(data=________, x="__________", color=NAVY, ax=ax)   # which chart? which column(s)?
#   ax.set_title("__________")
#   ax.set_xlabel("__________")
#   ax.set_ylabel("__________")
#   plt.show()

# --- your code below ---
fig, ax = plt.subplots()
sns.histplot(data=students, x="work_hours_per_week", color=NAVY, ax=ax)
ax.set_title("Weekly Work Hours for Northgate Students")
ax.set_xlabel("Work Hours per Week")
ax.set_ylabel("Number of Students")
plt.show()

# %% [markdown]
# **STAR story - Q1**
#
# **Scope:** This chart shows the number of hours per week that Northgate students work.
#
# **Track:** I am looking at how many hours per week Northgate students typically work, how spread out the hours are, and whether any values stand out.
#
# **Articulate:** Most students work about 10 to 25 hours per week, with many students around 15 to 20 hours. The values range from about 0 to 40 hours for most students.
#
# **Respond:** There is an unusual negative value near -10 hours, which does not make sense for weekly work hours. I would look at that student record to see if it is a dataentry error.

# %% [markdown]
# ### Q2 · One categorical variable
# **How does enrollment compare across majors?**
# → *sorted bar chart*. Column: `major` (from `students`).

# %%
# Copy the closest cell from the Guided notebook, then fill in the blanks.
#
#   fig, ax = plt.subplots()
#   sns.__________(data=________, x="__________", color=NAVY, ax=ax)   # which chart? which column(s)?
#   ax.set_title("__________")
#   ax.set_xlabel("__________")
#   ax.set_ylabel("__________")
#   plt.show()

# --- your code below ---

major_counts = students["major"].value_counts().sort_values(ascending=False)

fig, ax = plt.subplots()
sns.barplot(x=major_counts.values, y=major_counts.index, color=NAVY, ax=ax)
ax.set_title("Northgate Student Enrollment by Major")
ax.set_xlabel("Number of Students")
ax.set_ylabel("Major")
plt.show()

# %% [markdown]
# **STAR story - Q2**
#
# - **Scope —** This chart shows the number of Northgate students enrolled in each major.
# - **Track —** I am comparing enrollment across majors to see which majors have the most and least students.
# - **Articulate —** Cybersecurity has the highest enrollment with more than 500 students. Data Science, Information Science, and Information Technology each have around 280 students.
# - **Respond —** Some majors appear more than once with slightly different names, such as Cybersecurity and Cyber Security, and Data Science and DataScience. I would check these labels to see if they should be combined.

# %% [markdown]
# ### Q3 · A quantity, split by category
# **Does final GPA differ across majors?** Read the exceptions, not just the boxes.
# → *box plot per major*. Columns: `final_gpa` and `major` (from `students`).

# %%
# Copy the closest cell from the Guided notebook, then fill in the blanks.
#
#   fig, ax = plt.subplots()
#   sns.__________(data=________, x="__________", color=NAVY, ax=ax)   # which chart? which column(s)?
#   ax.set_title("__________")
#   ax.set_xlabel("__________")
#   ax.set_ylabel("__________")
#   plt.show()

# --- your code below ---

fig, ax = plt.subplots()
sns.boxplot(data=students, x="major", y="final_gpa", color=NAVY, ax=ax)
ax.set_title("Final GPA by Major")
ax.set_xlabel("Major")
ax.set_ylabel("Final GPA")
plt.xticks(rotation=45, ha="right")
plt.show()

# %% [markdown]
# **STAR story - Q3**
#
# - **Scope —** This chart shows the final GPA of Northgate students separated by major.
# - **Track —** I am comparing final GPA across majors to see whether some majors have higher or lower GPAs than others.
# - **Articulate —** Final GPA is fairly similar across the majors. Most median GPAs are around 2.2 to 2.5, and the ranges overlap considerably.
# - **Respond —** I noticed several unusually low GPA values, including some near 0. I would look more closely at those students to understand why their final GPA is so low.

# %% [markdown]
# ### Q4 · Two quantitative variables
# **Is there a relationship between how far students commute and their final GPA?** Remember: *association is not causation.*
# → *scatterplot with a trend line*. Columns: `commute_miles` and `final_gpa` (from `students`).

# %%
# Copy the closest cell from the Guided notebook, then fill in the blanks.
#
#   fig, ax = plt.subplots()
#   sns.__________(data=________, x="__________", color=NAVY, ax=ax)   # which chart? which column(s)?
#   ax.set_title("__________")
#   ax.set_xlabel("__________")
#   ax.set_ylabel("__________")
#   plt.show()

# --- your code below ---

fig, ax = plt.subplots()

sns.regplot(
    data=students,
    x="commute_miles",
    y="final_gpa",
    scatter_kws={"s": 12, "color": NAVY, "alpha": 0.4},
    line_kws={"color": RUST},
    ax=ax
)

ax.set_title("Final GPA vs. Commute Distance")
ax.set_xlabel("Commute Miles")
ax.set_ylabel("Final GPA")
plt.show()

# %% [markdown]
# **STAR story - Q4**
#
# - **Scope —** This chart shows the relationship between commute distance and final GPA for Northgate students.
# - **Track —** I am looking at whether students who commute farther tend to have different final GPAs.
# - **Articulate —** The trend line slopes downward, showing a negative association between commute distance and final GPA. Students with longer commutes tend to have lower GPAs, although there is a lot of variation.
# - **Respond —** I noticed several students with a final GPA of 0 and a few students with very long commutes. I would look at these students more closely and consider other factors before concluding that commute distance explains their GPA.

# %% [markdown]
# ### Q5 · Over time
# **How does student engagement change across the semester?**
# → *line chart* of average weekly activity. Use the `weekly` table: `week` and `minutes_active` (you'll need to average by week first — see the Guided notebook).

# %%
# Copy the closest cell from the Guided notebook, then fill in the blanks.
#
#   fig, ax = plt.subplots()
#   sns.__________(data=________, x="__________", color=NAVY, ax=ax)   # which chart? which column(s)?
#   ax.set_title("__________")
#   ax.set_xlabel("__________")
#   ax.set_ylabel("__________")
#   plt.show()

# --- your code below ---

weekly_avg = weekly.groupby("week")["minutes_active"].mean().reset_index()

fig, ax = plt.subplots()
sns.lineplot(data=weekly_avg, x="week", y="minutes_active",
             marker="o", color=NAVY, ax=ax)
ax.set_title("Northgate Student Engagement Across the Semester")
ax.set_xlabel("Week of Semester")
ax.set_ylabel("Average Minutes Active")
plt.show()

# %% [markdown]
# **STAR story - Q5**
#
# - **Scope —** This chart shows the average weekly active minutes of Northgate students across the semester.
# - **Track —** I am looking at how student engagement changes from week to week during the semester.
# - **Articulate —** Student engagement stays fairly consistent at around 210 average active minutes for most weeks. However, there is a large drop in Week 9 to about 90 minutes before activity returns to its normal level in Week 10.
# - **Respond —** Week 9 stands out because student activity drops much lower than every other week. I would look more closely at Week 9 to see what happened during that week.

# %% [markdown]
# # Part B — Your own question (open)
# Pose **one question of your own** about the Northgate students, choose the chart that answers it, build it, label it, and write its STAR story. Going beyond Part A is rewarded — a per-student line chart, a violin plot, or a chart of a messier column are all fair game.
#
# **Your question:** \_\_\_\_\_\_\_\_
#
# Does the number of advisor meetings differ across majors?

# %%
# Copy the closest cell from the Guided notebook, then fill in the blanks.
#
#   fig, ax = plt.subplots()
#   sns.__________(data=________, x="__________", color=NAVY, ax=ax)   # which chart? which column(s)?
#   ax.set_title("__________")
#   ax.set_xlabel("__________")
#   ax.set_ylabel("__________")
#   plt.show()

# --- your code below ---

fig, ax = plt.subplots()

sns.violinplot(
    data=students,
    x="major",
    y="advisor_meetings",
    color=NAVY,
    ax=ax
)

ax.set_title("Advisor Meetings by Major")
ax.set_xlabel("Major")
ax.set_ylabel("Number of Advisor Meetings")
plt.xticks(rotation=45, ha="right")
plt.show()

# %% [markdown]
# **STAR story - Part B**
#
# - **Scope —** This chart shows the number of advisor meetings for Northgate students across different majors.
# - **Track —** I am looking at whether the number of advisor meetings differs across majors.
# - **Articulate —** The distributions are very similar across most majors. Most students have around 1 to 3 advisor meetings, with the typical number around 2 meetings.
# - **Respond —** A few majors have students with much higher numbers of advisor meetings, reaching around 8 to 10. I would look more closely at those students to understand why they needed more meetings.

# %% [markdown]
# # Before you submit — checklist
# - [x] The notebook **runs top to bottom** with no errors (Runtime → Restart and run all).
# - [x] All **6 charts** are present, each with a title, labeled axes, and units/legend where needed.
# - [x] Each chart has a **complete STAR story**, including any exceptions you spotted.
# - [x] Part B question is written in and answered.
# - [x] Pushed to **GitHub**, and the **GitHub link** is submitted in Canvas.
#
# **Rubric (70 pts):** chart choice 10 · correct build 20 · labeling 10 · STAR reading 18 · Part B question 4 · submission & professionalism 8.
